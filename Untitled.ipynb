# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('gulbergData.xlsx')

# %%
df.head()
# Out:
#       Address RegisteredNumber
# 0  گلبرگ ٹاون                -
# 1  گلبرگ ٹاون                -
# 2  گلبرگ ٹاون                -
# 3  گلبرگ ٹاون                -
# 4  گلبرگ ٹاون                -

# %%
pd.to_numeric(df['RegisteredNumber'], errors='coerce').notnull().all()
# Out:
# False

# %%
result = df[ df.RegisteredNumber.str.isnumeric() == True) ]
# type(result)
# Out:
#   Cell In [9], line 1
#     result = df[ df.RegisteredNumber.str.isnumeric() == True) ]
#                                                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df['RegistryNo'] = df['RegisteredNumber'].str.strip()

# %%
df.head()
# Out:
#       Address RegisteredNumber RegistryNo
# 0  گلبرگ ٹاون                -          -
# 1  گلبرگ ٹاون                -          -
# 2  گلبرگ ٹاون                -          -
# 3  گلبرگ ٹاون                -          -
# 4  گلبرگ ٹاون                -          -

# %%
df_false = df[ df['RegistryNo'].str.isnumeric() == False  ]

# %%
df_numeric = df.drop(df['RegistryNo'].str.isnumeric() == False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df_numeric = df.drop(df['RegistryNo'].str.isnumeric() == False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df_false.head()
# Out:
#       Address RegisteredNumber RegistryNo
# 0  گلبرگ ٹاون                -          -
# 1  گلبرگ ٹاون                -          -
# 2  گلبرگ ٹاون                -          -
# 3  گلبرگ ٹاون                -          -
# 4  گلبرگ ٹاون                -          -

# %%
df_false['RegisteredNumber'].unique()
# Out:
# array(['-', '*', '1375-', '1542`', '17-46', '2093..', '2927+'],
#       dtype=object)

# %% [markdown]
# ## Start

# %%
indexNonNumeric = df[ df['RegistryNo'].str.isnumeric() == False  ].index 
df_numeric = df.drop(indexNonNumeric)

# %%
df_numeric.dtypes
# Out:
# Address             object
# RegisteredNumber    string
# RegistryNo          object
# dtype: object

# %%
df_numeric['RegisteredNumber'] = df_numeric['RegisteredNumber'].astype('string')

# %%
df_numeric [ df_numeric['RegisteredNumber'].str.contains('.') == True  ]
# Out:
#           Address RegisteredNumber RegistryNo
# 13     گلبرگ ٹاون             2406        NaN
# 14     گلبرگ ٹاون             2908        NaN
# 16     گلبرگ ٹاون           0.1536        NaN
# 17     گلبرگ ٹاون           0.2316        NaN
# 18     گلبرگ ٹاون           0.2486        NaN
# ...           ...              ...        ...
# 42582  گلبرگ ٹاون              999        NaN
# 42583  گلبرگ ٹاون              999        NaN
# 42584  گلبرگ ٹاون              999        NaN
# 42585  گلبرگ ٹاون              999        NaN
# 42586  گلبرگ ٹاون              999        NaN
#
# [42568 rows x 3 columns]
